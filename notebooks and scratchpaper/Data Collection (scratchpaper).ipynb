# %% [markdown]
# # Data Collection

# %% [markdown]
# <hr>

# %% [markdown]
# Get an understanding of how [this](https://github.com/lmeazzini/youtube-recommender/blob/master/src/data_science/search_data_collection.py) works.

# %%
import time
import requests
import yaml

# %% [markdown]
# This isn't working :(

# %%
# open the .yaml file for parameters
with open('../parameters.yaml') as f:
    params = yaml.load(f, Loader=yaml.FullLoader)

# gets the parametesr from the .yaml file
queries = params['queries']
urls = params['urls']
number_of_pages = params['number_of_pages']

# Collecting data from youtube pages
for query in queries:
    for page in range(1, number_of_pages+1):
        url = urls.format(query=query, page=page)
        response = requests.get(url)

        with open('../../pages/{}_{}.html'.format(query,
                                                  page), 'w+') as output:
            output.write(response.text)

        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-07c430ddeabe> in <module>
#      12         response = requests.get(url)
#      13
# ---> 14         with open('../../pages/{}_{}.html'.format(query,
#      15                                                   page), 'w+') as output:
#      16             output.write(response.text)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../pages/folk+rock_1.html'

# %% [markdown]
# <hr>

# %% [markdown]
# New tutorial [here](https://www.youtube.com/watch?v=th5_9woFJmk). hehe

# %% [markdown]
# Load API key from the txt file. (There's probably a better way to do this, but oh well!)

# %%
API_KEY = ""

with open("../YouTube API Key.txt") as f:
    for line in f:
        API_KEY = line

# %% [markdown]
# Reference: https://github.com/googleapis/google-api-python-client
# Another reference: https://googleapis.github.io/google-api-python-client/docs/dyn/youtube_v3.html

# %% [markdown]
# ## Create the YouTube Service object

# %% [markdown]
# Get the YouTube service to let us work with the APIs

# %%
# Allows us to connect to the YouTube API service
from googleapiclient.discovery import build

# the service
youtube_service = build('youtube', 'v3', developerKey=API_KEY)

# %% [markdown]
# Simple API request as a test (from the tutorial video)

# %%
request = youtube_service.channels().list(
            part='statistics',
            forUsername='schafer5'
        )

# %%
response = request.execute()

# %%
print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'lXXlwIGiu-wf7INz1lLPOZIg9Bo', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': '9ZvbmSCHow8TQjfuamaR6SnAnrA', 'id': 'UCCezIgC97PvUuR4_gbFUs5g', 'statistics': {'viewCount': '53160693', 'subscriberCount': '729000', 'hiddenSubscriberCount': False, 'videoCount': '230'}}]}

# %% [markdown]
# :)!

# %% [markdown]
# ## List YouTube videos based off search keywords

# %% [markdown]
# *Now let's figure out how to search for YouTube music videos based on keywords.*

# %%
search_terms = 'xKito'
MUSIC_CATEGORY_ID = 10

# %%
MUSIC_CATEGORY_ID = 10

request = youtube_service.search().list(
            part='snippet',
            maxResults=50,
            q=search_terms,
            type='video',
            videoCategoryId = MUSIC_CATEGORY_ID,
            )

# %%
response = request.execute()

# %%
print(response)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': 'Opf4m43SnG1mhHpgQffTxtmYXnA', 'nextPageToken': 'CDIQAA', 'regionCode': 'US', 'pageInfo': {'totalResults': 144, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'AtCsHT1G8_iu3dLheZ4-WGEu6kI', 'id': {'kind': 'youtube#video', 'videoId': 'cy_6ZKurLS4'}, 'snippet': {'publishedAt': '2021-01-09T17:03:55Z', 'channelId': 'UCs4zWdCrlnXmpVkjOgAHs0w', 'title': '【DTM】PSYQUIさんとDTMや音楽について熱く語ります。', 'description': 'ばーちゃるとらっくめーかー。DTMや音楽の動画をあげてます。 たまにゲームや雑談なども。 アニメやゲーム、Vtuberさん等に楽曲提供してます。', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/cy_6ZKurLS4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/cy_6ZKurLS4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/cy_6ZKurLS4/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'ミディ / 作曲Vtuber', 'liveBroadcastContent': 'none', 'publishTime': '2021-01-09T17:03:55Z'}}, {'kind': 'youtube#searchResult', 'etag': 'D6fx-vL1Lu0wjGFegGo8seERQ70', 'id': {'kind': 'youtube#video', 'videoId': 'UXDpzr6YJlk'}, 'snippet': {'publishedAt': '2020-08-23T01:58:13Z', 'channelId': 'UCFCNtJPlm_lR1tNB1j0kPAA', 'title': '[初生放送]ヒステリックナイトガール解説とギター雑談', 'description': 'ヒステリックナイトガール解説 イントロ1 4:58 Aメロ1 9:15 Bメロ1 12:11 サビ1 14:00 イントロ 17:20 Aメロ2 18:17 20:00 Bメロ2 24:18 サビ2 25:46 ソロ 28:41 Cメロ ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UXDpzr6YJlk/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/UXDpzr6YJlk/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/UXDpzr6YJlk/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'N K', 'liveBroadcastContent': 'none', 'publishTime': '2020-08-23T01:58:13Z'}}, {'kind': 'youtube#searchResult', 'etag': 'BpbhoFaxoi-JBbgsIeUFBAV3zas', 'id': {'kind': 'youtube#video', 'videoId': 'D86YciZ06I0'}, 'snippet': {'publishedAt': '2020-11-16T14:25:02Z', 'channelId': 'UC8ZFzVRNt_FH9lX_pR5M09Q', 'title': '#電音部 -企画会議-シブヤvol.1', 'description': '番組内容 『電音部』の楽曲情報や最新情報をお届けするとともに、 今後のプロジェクトについて考えていきたいと思います！ □出演 MC 白石稔 キャスト 健屋花那(鳳凰火凛 ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D86YciZ06I0/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/D86YciZ06I0/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/D86YciZ06I0/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'ASOBINOTES公式チャンネル', 'liveBroadcastContent': 'none', 'publishTime': '2020-11-16T14:25:02Z'}}, {'kind': 'youtube#searchResult', 'etag': 'YHtPuNPGsMFnoTJfdJ31v0Pi3yY', 'id': {'kind': 'youtube#video', 'videoId': 'v64VKMVfin4'}, 'snippet': {'publishedAt': '2020-07-05T12:47:45Z', 'channelId': 'UCIdEIHpS0TdkqRkHL5OkLtA', 'title': '【20万人記念配信】バーチャルサナトリウムカラオケ部', 'description': 'Vtuberっぽい…！チャンネル登録者20万人を記念して歌やります！！！！！ にがてながら……たのしんでもらえるようにがんばります！ ※他の方が歌ったものと合わせた ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/v64VKMVfin4/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/v64VKMVfin4/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/v64VKMVfin4/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle': 'さなちゃんねる', 'liveBroadcastContent': 'none', 'publishTime': '2020-07-05T12:47:45Z'}}, {'kind': 'youtube#searchResult', 'etag': 'IFfZpfDuzHjHNCZx2vgoHblu4Vg', 'id': {'kind': 'youtube#video', 'videoId': '47WKdZtxBZE'}, 'snippet': {'publishedAt': '2020-01-02T01:38:30Z', 'channelId': 'UCH0bhP_bI7jpkaUqzBq26hA', 'title': 'Making MuseScore Piano Transcriptions!', 'description': 'Thank you for stopping by to listen doing today: graphite/diamond psyqui - funk assembly.', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/47WKdZtxBZE/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/47WKdZtxBZE/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/47WKdZtxBZE/hqdefault. ...

# %% [markdown]
# How to retrieve individual items (each item is a youtube video from the search)

# %%
response['items'][1]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '9-mK4cAIpWSe6Hz0fNj8BP2FTZI',
#  'id': {'kind': 'youtube#video', 'videoId': 'Jhq_44IotCM'},
#  'snippet': {'publishedAt': '2019-09-09T17:47:12Z',
#   'channelId': 'UCwobzUc3z-0PrFpoRxNszXQ',
#   'title': 'Study Music, Work Music, Focus, Concentration, Meditation, Relaxing Music, Calm Music, Study,\xa0☯3601',
#   'description': 'Study Music, Work Music, Focus, Concentration, Meditation, Relaxing Music, Calm Music, Study, ☯3601 - Are you looking for studying music, focus music or ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Jhq_44IotCM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Jhq_44IotCM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Jhq_44IotCM/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Yellow Brick Cinema - Relaxing Music',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2019-09-09T17:47:12Z'}}

# %% [markdown]
# ## Getting More Info Per Video (using the same API request as listing search results)
# Note after looking at stuff more: let's just use this API to get the list of video ID's, and then use the next one (`videos().list`) to get the actual info (because there's way more info available through that one, and I think it would be easier to do it all there)

# %% [markdown]
# Getting individual info on each item

# %% [markdown]
# How we get the <font color="red">youtube URL</font>

# %%
response['items'][1]['id']['videoId']
# Out:
# 'Jhq_44IotCM'

# %%
print('https://www.youtube.com/watch?v='+response['items'][1]['id']['videoId'])
# Out:
# https://www.youtube.com/watch?v=Jhq_44IotCM

# %% [markdown]
# How to iterate through all the items **on the first page**
# (figure out how to iterate through pages next)
# <font color='red'>*Todo: edit this so it goes through more than just the first page*</font>

# %%
list_of_ids = []

for item in response['items']:
    list_of_ids.append(item['id']['videoId'])

list_of_ids
# Out:
# ['hVUrtS77kgM',
#  '5n9FWGUm2pc',
#  'gMZhRJ5354o',
#  '18zTOaTENLA',
#  'Xs_HdCFbhJI',
#  'Bwb5D-ILhAQ',
#  'Hr_Oe4kQgYE',
#  'eDJ8wSdleRw',
#  'c-EkFgViaPE',
#  'Nu56cTqohlM',
#  'N11sB7ggzdw',
#  'Tc-XxqEyolU',
#  '_8dh_MzO_nU',
#  'bZnR9QwbbxI',
#  '2nLzFxeZ9Zo',
#  '08wKGQRkg_U',
#  '944IATvLj-4',
#  '3L65PG_eZFg',
#  'F8gPLTk_ehQ',
#  'EeVaNmytazM',
#  'rCwSmEZ1Jyc',
#  'LWn28sKDWXo',
#  'Dhu3VSj-qnk',
#  '4zF2hldTyfs',
#  'sQFo1Ekmnv8',
#  'WbBLWOwNRmg',
#  'c-La-lVYPro',
#  'kndYAscsEDM',
#  'yG30yDhpNps',
#  '0DymLlXPq9c',
#  'mvpw-E6IU_c',
#  'snfo9Pq_HOE',
#  'Gp0sqq1Uh0w',
#  'WSNFVE3MUdc',
#  'JxHc0dp2zDI',
#  'WRDWRJMAsAo',
#  'hQ2mBuU1Q3M',
#  'EbV3boFOMII',
#  'fBRBnSvbWQ8',
#  'oIMRZU2w83w',
#  'MqoCXM9xsfA',
#  'BVBdqkHNl54',
#  'DMiQw0BLMnY',
#  'vQQ8fsbb-lg',
#  'kKfBb8zUM3U',
#  'IRD7WylAfkw',
#  'tRuM4zD48AA',
#  'lvMowQI0fHI',
#  'iqfS8C8awlY',
#  'DqNvIW-us-c']

# %% [markdown]
# To get the next page:

# %%
last_request = request
last_response = response

# %%
request = youtube_service.search().list_next(
                                        previous_request = last_request,
                                        previous_response = last_response)

# %%
response = request.execute()

# %%
for item in response['items']:
    print(item['snippet']['title'])
    print()
# Out:
# ['study music', 'concentration music', 'focus music', 'study', 'relaxing music', 'studying music', 'focus', 'stress relief music', 'calm music', 'meditation music', 'alpha waves', 'background music', 'music for studying', 'brain power', 'calm music for studying', 'binaural beats', 'meditation', 'concentration', 'stress relief', 'work music', 'homework', 'intelligence', 'quarantine', 'memory', 'mindfulness', 'music for memory', 'relax', 'music for study work', 'music to study', 'zen music', 'yoga', 'yoga music', 'reading music', 'yellow brick cinema']

# %% [markdown]
# ## More Info on Videos (new API request)

# %% [markdown]
# part can contain: contentDetails, fileDetails, id, liveStreamingDetails, localizations, player, processingDetails, recordingDetails, snippet, statistics, status, suggestions, topicDetails

# %% [markdown]
# See info here: https://developers.google.com/youtube/v3/docs/videos

# %% [markdown]
# <font color='red'>*Todo: look at what data here may be useful to save*</font>

# %%
request = youtube_service.videos().list(
            part='snippet',
            id=list_of_ids)

# %%
response = request.execute()

# %%
print(response)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'EQhjsKgPA7bzUEtMvxyJfy2mEnU', 'items': [{'kind': 'youtube#video', 'etag': '8uD89cCnitEIL9WCaqvfm6bFBk8', 'id': 'hVUrtS77kgM', 'snippet': {'publishedAt': '2021-03-09T17:16:00Z', 'channelId': 'UCMOgdURr7d8pOVlc-alkfRg', 'title': '🎵  Progressive House/Trance Mix 2021 🎵', 'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com", 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'xKito Music', 'tags': ['electro', 'electronic', 'dance', 'music', 'EDM', 'xkito', 'xkitomusic', 'anime', 'animation', 'kito', 'gif', 'prog house', 'prog', 'progressive', 'house', 'trance', 'progressive house', 'progressive trance', 'mix', 'compilation', 'playlist'], 'categoryId': '10', 'liveBroadcastContent': 'none', 'localized': {'title': '🎵  Progressive House/Trance Mix 2021 🎵', 'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're i ...

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#video',
#  'etag': '8uD89cCnitEIL9WCaqvfm6bFBk8',
#  'id': 'hVUrtS77kgM',
#  'snippet': {'publishedAt': '2021-03-09T17:16:00Z',
#   'channelId': 'UCMOgdURr7d8pOVlc-alkfRg',
#   'title': '🎵  Progressive House/Trance Mix 2021 🎵',
#   'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'xKito Music',
#   'tags': ['electro',
#    'electronic',
#    'dance',
#    'music',
#    'EDM',
#    'xkito',
#    'xkitomusic',
#    'anime',
#    'animation',
#    'kito',
#    'gif',
#    'prog house',
#    'prog',
#    'progressive',
#    'house',
#    'trance',
#    'progressive house',
#    'progressive trance',
#    'mix',
#    'compilation',
#    'playlist'],
#   'categoryId': '10',
#   'liveBroadcastContent': 'none',
#   'localized': {'title': '🎵  Progressive House/Trance Mix 2021 🎵',
#    'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com"}}}

# %%
response['items'][0]['snippet']
# Out:
# {'publishedAt': '2021-03-09T17:16:00Z',
#  'channelId': 'UCMOgdURr7d8pOVlc-alkfRg',
#  'title': '🎵  Progressive House/Trance Mix 2021 🎵',
#  'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com",
#  'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/default.jpg',
#    'width': 120,
#    'height': 90},
#   'medium': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/mqdefault.jpg',
#    'width': 320,
#    'height': 180},
#   'high': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/hqdefault.jpg',
#    'width': 480,
#    'height': 360},
#   'standard': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/sddefault.jpg',
#    'width': 640,
#    'height': 480},
#   'maxres': {'url': 'https://i.ytimg.com/vi/hVUrtS77kgM/maxresdefault.jpg',
#    'width': 1280,
#    'height': 720}},
#  'channelTitle': 'xKito Music',
#  'tags': ['electro',
#   'electronic',
#   'dance',
#   'music',
#   'EDM',
#   'xkito',
#   'xkitomusic',
#   'anime',
#   'animation',
#   'kito',
#   'gif',
#   'prog house',
#   'prog',
#   'progressive',
#   'house',
#   'trance',
#   'progressive house',
#   'progressive trance',
#   'mix',
#   'compilation',
#   'playlist'],
#  'categoryId': '10',
#  'liveBroadcastContent': 'none',
#  'localized': {'title': '🎵  Progressive House/Trance Mix 2021 🎵',
#   'description': "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com"}}

# %%
response['items'][0]['snippet']['title']
# Out:
# '🎵  Progressive House/Trance Mix 2021 🎵'

# %%
response['items'][0]['snippet']['description']
# Out:
# "👕 OFFICIAL XKITO MERCH STORE: http://dbh.la/xkito\n💚 Official xKito Music Spotify Playlist: https://spoti.fi/3c43dZN\n\n\n👉 Tracklist:\n00:00 - 02:54 Tritonal ft. Angel Taylor - Getaway (Axis Remix)\n02:54 - 07:12 Adrian Alexander & Thomas Mengel - Timewalker\n07:12 - 10:43 Thomas Hayes – Cirrus (Adrian Alexander Remix)\n10:43 - 15:22 Farius - Initio (Farius Club Mix)\n15:22 - 18:40 Kapera - Feelin You (feat. Lauren L'aimant)\n18:40 - 21:56 Paul Arcane & Scolario - Voices\n21:56 - 25:55 Rodrigo Deem - You Said It All (feat. KARRA)\n25:55 - 29:50 Koyah & Deakin XD - All I Wanted\n29:50 - 34:36 Warsongs - Piercing Light (Mako Remix)\n\n\n⭐️ xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/xkito.music/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n📄 Submit your music or art to xKito:\nYou can now submit your music/art directly to xKito through the submission platform! You can also submit your unreleased music as a label release if you're interested in releasing with xKito Records! All you need to do is sign up on the platform below and you can instantly submit! You will be notified shortly whether your submission was accepted or denied.\nLink to platform: https://xkitomusic.edmdistrict.com/signup\n\n\n👾 AMATISTA studio | best live wallpapers\nhttps://www.youtube.com/AmatistaStudio\u200b\nWallpaper: https://youtu.be/95a8XU2oIV8\nDownload: https://ouo.io/1HFdaW\n🖼 PICTURE from: Honkai Impact 3rd\n\n\n❗️ Usage Policy:\n✅ You may use this playlist for streaming or in your YouTube videos\n\n\n➖➖➖➖➖➖➖➖➖➖➖➖\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com"

# %%
response['items'][0]['snippet']['tags']
# Out:
# ['electro',
#  'electronic',
#  'dance',
#  'music',
#  'EDM',
#  'xkito',
#  'xkitomusic',
#  'anime',
#  'animation',
#  'kito',
#  'gif',
#  'prog house',
#  'prog',
#  'progressive',
#  'house',
#  'trance',
#  'progressive house',
#  'progressive trance',
#  'mix',
#  'compilation',
#  'playlist']

# %% [markdown]
# <hr>

# %%
# Allows us to connect to the YouTube API service
from googleapiclient.discovery import build
import math

# %%
API_KEY = ""

# Read in the API key
with open("../YouTube API Key.txt") as f:
    for line in f:
        API_KEY = line

# Create the service
youtube_service = build('youtube', 'v3', developerKey=API_KEY)

# %%
keywords = ['xkito', 'electric swing','reol','animal crossing']

# %%
def search_videos(search_terms, pages=5, results_per_page = 50):
    """
    Search videos on YouTube given a list of various keywords or key phrases.
    Return a list of YouTube video IDs.
    
    search_terms: a list of search terms. each search term will be a new search
    pages: the number of pages we want to retrieve per search (default 5)
    results_per_page: the number of results per page we want to retrieve per search (max is 50)
    returns a list of video ids
    
    """
    
    # initialize empty list to store video ids
    list_of_ids = []
    
    # ID for the video category of music is 10
    MUSIC_CATEGORY_ID = 10

    for search_term in search_terms:
        
        # get the first page of videos for the search term
        request = youtube_service.search().list(
                    part='snippet',
                    maxResults=results_per_page,
                    q=search_term,
                    type='video',
                    videoCategoryId = MUSIC_CATEGORY_ID,
                    )
        response = request.execute()

        # iterate through the response and save just the video id's
        for item in response['items']:
            list_of_ids.append(item['id']['videoId'])
                
        # we already searched once, so get the remaining X-1 pages (where X is number of pages)
        for page in range(1, pages):
            last_request = request
            last_response = response

            request = youtube_service.search().list_next(
                                    previous_request = last_request,
                                    previous_response = last_response)
            response = request.execute()
            
            # iterate through the response and save just the video id's
            for item in response['items']:
                list_of_ids.append(item['id']['videoId'])

    # done!    
    return list_of_ids

# %%
ids = search_videos(keywords)

# %%
def get_video_data(video_ids):
    """
    Saves a csv (for now) of video data.
    
    video_ids: the list of video ids
    """

# %% [markdown]
# Note: can only do 50 at a time?

# %%
math.ceil(len(ids)/50)
# Out:
# 20

# %%
len(ids)
# Out:
# 1000

# %%
request = youtube_service.videos().list(
            part='snippet, contentDetails, statistics, topicDetails',
            id=ids[950:])

response = request.execute()

# %%
response['items'][0]
# Out:
# {'kind': 'youtube#video',
#  'etag': 'GNS319mc0jP8MQV9Nm_mipul6EA',
#  'id': 'DqNvIW-us-c',
#  'snippet': {'publishedAt': '2017-11-13T19:15:22Z',
#   'channelId': 'UCMOgdURr7d8pOVlc-alkfRg',
#   'title': 'MARNIK - Burn (feat. Rookies)',
#   'description': '♫ Buy/Stream: https://marnik.lnk.to/burn\n\n\n[Genre: Electronic/Pop]\n\n[Label: UMG Recordings]\n\n\n►Marnik:\nhttps://soundcloud.com/marnikofficial\nhttps://www.facebook.com/Marnikofficial/\nhttps://twitter.com/marnikofficial\nhttps://www.instagram.com/marnikofficial/\nhttps://www.youtube.com/marnikofficial\n\n\n►Rookies:\nhttps://soundcloud.com/r0okies\nhttps://twitter.com/r0okies\nhttps://www.instagram.com/r0okies/\nhttps://www.facebook.com/r0okies\nhttps://twitter.com/r0okies\nhttps://www.youtube.com/channel/UCI0OcrtsHQbGWIlKNjllX7Q\n\n\n►xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/belgin.xk/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n►Submit your music to xKito:\nhttps://goo.gl/mQkm4u\n\n\n►SUBMIT YOUR ARTWORK!\nYou like to draw and would like your art to be featured on an xKito Music Video? Submit it here →\nhttps://goo.gl/uKfWmj\n\n\n►PICTURE → https://youtu.be/2gU_HpD0hWY\n©Artwork from: League of Legends\n\n\n►Usage Policy:\n✖ Please get in touch with the label for usage of this track in your Youtube videos.\n\n\n- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DqNvIW-us-c/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/DqNvIW-us-c/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/DqNvIW-us-c/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/DqNvIW-us-c/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/DqNvIW-us-c/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'channelTitle': 'xKito Music',
#   'tags': ['electro',
#    'electronic',
#    'dance',
#    'music',
#    'EDM',
#    'xkito',
#    'xkitomusic',
#    'anime',
#    'animation',
#    'kito',
#    'gif',
#    'marnik',
#    'burn',
#    'rookies',
#    'MARNIK - Burn (feat. Rookies)',
#    'ft. rookies',
#    'pop',
#    'house'],
#   'categoryId': '10',
#   'liveBroadcastContent': 'none',
#   'localized': {'title': 'MARNIK - Burn (feat. Rookies)',
#    'description': '♫ Buy/Stream: https://marnik.lnk.to/burn\n\n\n[Genre: Electronic/Pop]\n\n[Label: UMG Recordings]\n\n\n►Marnik:\nhttps://soundcloud.com/marnikofficial\nhttps://www.facebook.com/Marnikofficial/\nhttps://twitter.com/marnikofficial\nhttps://www.instagram.com/marnikofficial/\nhttps://www.youtube.com/marnikofficial\n\n\n►Rookies:\nhttps://soundcloud.com/r0okies\nhttps://twitter.com/r0okies\nhttps://www.instagram.com/r0okies/\nhttps://www.facebook.com/r0okies\nhttps://twitter.com/r0okies\nhttps://www.youtube.com/channel/UCI0OcrtsHQbGWIlKNjllX7Q\n\n\n►xKito Music:\nhttps://www.facebook.com/xKitoMusic\nhttps://twitter.com/xkito_music\nhttps://instagram.com/belgin.xk/\nhttps://soundcloud.com/xkitomusic\nhttps://www.youtube.com/c/xKitoMusic\n\n\n►Submit your music to xKito:\nhttps://goo.gl/mQkm4u\n\n\n►SUBMIT YOUR ARTWORK!\nYou like to draw and would like your art to be featured on an xKito Music Video? Submit it here →\nhttps://goo.gl/uKfWmj\n\n\n►PICTURE → https://youtu.be/2gU_HpD0hWY\n©Artwork from: League of Legends\n\n\n►Usage Policy:\n✖ Please get in touch with the label for usage of this track in your Youtube videos.\n\n\n- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -\n\nFor business inquiries and other issues please contact xkitomusic@gmail.com'}},
#  'contentDetails': {'duration': 'PT3M14S',
#   'dimension': '2d',
#   'definition': 'hd',
#   'caption': 'false',
#   'licensedContent': False,
#   'contentRating': {},
#   'projection': 'rectangular'}}

# %%
response['items'][0]['snippet']['title']
# Out:
# 'Prologue (Campfire) - Animal Crossing: New Horizons Music Extended [OST]'

# %%
response['items'][0]['snippet']['description']
# Out:
# 'Animal Crossing: New Horizons music that has been extended to play for at least 15.5 minutes.\n\nComposer(s): Yasuaki Iwata, Yumi Takahashi, Shinobu Nagata, Sayako Doi, Masato Ohashi\nArranger(s): Yasuaki Iwata, Yumi Takahashi, Shinobu Nagata, Sayako Doi, Masato Ohashi\n\nDeveloper(s): Nintendo, Nintendo Entertainment Planning & Development\nPublisher(s): Nintendo\n\nFull Playlist: https://www.youtube.com/playlist?list=PLsz7MwL4fp2LjGFdIus90HPfI6BYINSx8\n\nPlease Subscribe and Like to Keep this Channel Going, It Genuinely Helps.\n\nSocial Media: https://mobile.twitter.com/cellextyn'

# %%
try:
    print(response['items'][0]['snippet']['tags'])
except:
    print("No tags")
# Out:
# No tags

# %%
response['items'][0]['snippet']['channelTitle']
# Out:
# 'Cellextyn X'

# %%
response['items'][0]['snippet']['localized']['title']
# Out:
# 'Prologue (Campfire) - Animal Crossing: New Horizons Music Extended [OST]'

# %%
response['items'][0]['snippet']['localized']['description']
# Out:
# 'Animal Crossing: New Horizons music that has been extended to play for at least 15.5 minutes.\n\nComposer(s): Yasuaki Iwata, Yumi Takahashi, Shinobu Nagata, Sayako Doi, Masato Ohashi\nArranger(s): Yasuaki Iwata, Yumi Takahashi, Shinobu Nagata, Sayako Doi, Masato Ohashi\n\nDeveloper(s): Nintendo, Nintendo Entertainment Planning & Development\nPublisher(s): Nintendo\n\nFull Playlist: https://www.youtube.com/playlist?list=PLsz7MwL4fp2LjGFdIus90HPfI6BYINSx8\n\nPlease Subscribe and Like to Keep this Channel Going, It Genuinely Helps.\n\nSocial Media: https://mobile.twitter.com/cellextyn'

# %%
response['items'][0]['contentDetails']['duration']
# Out:
# 'PT30M2S'

# %% [markdown]
# Come back to this later maybe

# %%
response['items'][0]['contentDetails']['contentRating']
# Out:
# {}

# %%
response['items'][40]['statistics']
# Out:
# {'viewCount': '130022',
#  'likeCount': '13984',
#  'dislikeCount': '12',
#  'favoriteCount': '0',
#  'commentCount': '574'}

# %%
response['items'][30]['topicDetails']
# Out:
# {'topicCategories': ['https://en.wikipedia.org/wiki/Music']}
